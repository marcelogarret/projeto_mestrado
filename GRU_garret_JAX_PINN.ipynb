# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelogarret/projeto_mestrado/blob/main/GRU_garret_JAX_PINN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install --upgrade pip
# %pip install --upgrade "jax[cuda]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html optax flax
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-24.3.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-24.3.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 43.0 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-24.3.1
# Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Requirement already satisfied: optax in /usr/local/lib/python3.10/dist-packages (0.2.3)
# Requirement already satisfied: flax in /usr/local/lib/python3.10/dist-packages (0.8.5)
# Collecting flax
#   Downloading flax-0.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: jax[cuda] in /usr/local/lib/python3.10/dist-packages (0.4.33)
# Collecting jax[cuda]
#   Downloading jax-0.4.35-py3-none-any.whl.metadata (22 kB)
# Collecting jaxlib<=0.4.35,>=0.4.34 (from jax[cuda])
#   Downloading jaxlib-0.4.35-cp310-cp310-manylinux2014_x86_64.whl.metadata (983 bytes)
# Requirement already satisfied: ml-dtypes>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from jax[cuda]) (0.4.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.10/dist-packages (from jax[cuda]) (1.26.4)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax[cuda]) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax[cuda]) (1.13.1)
#   Downloading jaxlib-0.4.34-cp310-cp310-manylinux2014_x86_64.whl.metadata (983 bytes)
# Collecting jax-cuda12-plugin<=0.4.35,>=0.4.34 (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda])
#   Downloading jax_cuda12_plugin-0.4.35-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from optax) (1.4.0)
# Requirement already satisfied: chex>=0.1.86 in /usr/local/lib/python3.10/dist-packages (from optax) (0.1.87)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.10/dist-packages (from optax) (1.10.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from flax) (1.1.0)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.10/dist-packages (from flax) (0.6.4)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.10/dist-packages (from flax) (0.1.66)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.10/dist-packages (from flax) (13.9.3)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.10/dist-packages (from flax) (4.12.2)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from flax) (6.0.2)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.86->optax) (0.12.1)
# Collecting jax-cuda12-pjrt==0.4.35 (from jax-cuda12-plugin<=0.4.35,>=0.4.34->jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda])
#   Downloading jax_cuda12_pjrt-0.4.35-py3-none-manylinux2014_x86_64.whl.metadata (349 bytes)
# Requirement already satisfied: nvidia-cublas-cu12>=12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (12.6.3.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12>=12.1.105 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (12.6.80)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12>=12.1.105 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12>=12.1.105 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (12.6.77)
# Requirement already satisfied: nvidia-cudnn-cu12<10.0,>=9.1 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (9.5.0.50)
# Requirement already satisfied: nvidia-cufft-cu12>=11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (11.3.0.4)
# Requirement already satisfied: nvidia-cusolver-cu12>=11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12>=12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (12.5.4.2)
# Requirement already satisfied: nvidia-nccl-cu12>=2.18.1 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (2.23.4)
# Requirement already satisfied: nvidia-nvjitlink-cu12>=12.1.105 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (12.6.77)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax) (2.18.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax) (1.6.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax) (3.20.3)
# Requirement already satisfied: humanize in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax) (4.10.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax) (0.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epy]->optax) (2024.6.1)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epy]->optax) (6.4.5)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epy]->optax) (3.20.2)
# Downloading jaxlib-0.4.34-cp310-cp310-manylinux2014_x86_64.whl (86.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.1/86.1 MB 43.9 MB/s eta 0:00:00
# Downloading flax-0.10.0-py3-none-any.whl (420 kB)
# Downloading jax-0.4.35-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 57.2 MB/s eta 0:00:00
# Downloading jax_cuda12_plugin-0.4.35-cp310-cp310-manylinux2014_x86_64.whl (15.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 64.6 MB/s eta 0:00:00
# Downloading jax_cuda12_pjrt-0.4.35-py3-none-manylinux2014_x86_64.whl (100.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 MB 45.7 MB/s eta 0:00:00
# Installing collected packages: jax-cuda12-pjrt, jax-cuda12-plugin, jaxlib, jax, flax
#   Attempting uninstall: jax-cuda12-pjrt
#     Found existing installation: jax-cuda12-pjrt 0.4.33
#     Uninstalling jax-cuda12-pjrt-0.4.33:
#       Successfully uninstalled jax-cuda12-pjrt-0.4.33
#   Attempting uninstall: jax-cuda12-plugin
#     Found existing installation: jax-cuda12-plugin 0.4.33
#     Uninstalling jax-cuda12-plugin-0.4.33:
#       Successfully uninstalled jax-cuda12-plugin-0.4.33
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.33
#     Uninstalling jaxlib-0.4.33:
#       Successfully uninstalled jaxlib-0.4.33
#   Attempting uninstall: jax
#     Found existing installation: jax 0.4.33
#     Uninstalling jax-0.4.33:
#       Successfully uninstalled jax-0.4.33
#   Attempting uninstall: flax
#     Found existing installation: flax 0.8.5
#     Uninstalling flax-0.8.5:
#       Successfully uninstalled flax-0.8.5
# Successfully installed flax-0.10.0 jax-0.4.35 jax-cuda12-pjrt-0.4.35 jax-cuda12-plugin-0.4.35 jaxlib-0.4.34

# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import jax
import jax.numpy as jnp
from jax import random, grad, vmap, jit, value_and_grad
import flax.linen as nn
from flax.training.train_state import TrainState
import optax
from functools import partial

# %%
## Importação do histórico - UNISIM
df = pd.read_excel('/content/drive/MyDrive/UNISIM/dataset_unisim.xlsx')
df.head()
# Out:
#      t      Np        Gp  Wp  Winj        Bo        Bg      Rs      Viso  \
# 0    0       0         0   0     0  1.394241  0.003249  113.06  0.638284
# 1   31   61938   6858068   0     0  1.394403  0.003260  113.06  0.640304
# 2   62  124403  13532213   0     0  1.394727  0.003281  113.06  0.644361
# 3   92  182423  20112443   0     0  1.394889  0.003291  113.06  0.646399
# 4  123  244857  26856741   0     0  1.395051  0.003302  113.06  0.648443
#
#        Visg    p
# 0  0.027344  332
# 1  0.027288  331
# 2  0.027178  329
# 3  0.027122  328
# 4  0.027067  327

# %%
df.shape
# Out:
# (132, 11)

# %%
df.index = df['t']
df2 = df.copy()
df2.drop('t', axis=1, inplace=True)
df2.drop('Rs', axis=1, inplace=True)
df2.head()
# Out:
#          Np        Gp  Wp  Winj        Bo        Bg      Viso      Visg    p
# t
# 0         0         0   0     0  1.394241  0.003249  0.638284  0.027344  332
# 31    61938   6858068   0     0  1.394403  0.003260  0.640304  0.027288  331
# 62   124403  13532213   0     0  1.394727  0.003281  0.644361  0.027178  329
# 92   182423  20112443   0     0  1.394889  0.003291  0.646399  0.027122  328
# 123  244857  26856741   0     0  1.395051  0.003302  0.648443  0.027067  327

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Separar as características e o rótulo
features = df2.iloc[:, :-1]  # Todas as colunas exceto a última
# features = df2.iloc[:, 1:-1]  # Todas as colunas menos a última e a primeira (t)
labels = df2.iloc[:, -1]     # Última coluna

# Normalizar as características
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(features)

# Combinar as características normalizadas e a coluna de rótulos não normalizada
scaled_data = np.concatenate([scaled_features, labels.values.reshape(-1, 1)], axis=1)
# scaled_data = np.concatenate([features, labels.values.reshape(-1, 1)], axis=1)
# scaled_data = df2.to_numpy()

scaled_data.shape, scaled_data[0], labels
# Out:
# ((132, 9),
#  array([  0.,   0.,   0.,   0.,   0.,   0.,   0.,   1., 332.]),
#  t
#  0       332
#  31      331
#  62      329
#  92      328
#  123     327
#         ...
#  3867    305
#  3896    306
#  3927    307
#  3957    308
#  3988    309
#  Name: p, Length: 132, dtype: int64)

# %%
# Dicionários para armazenar X e y para cada valor de window_size
datasets = {}

# Gerar os datasets X e y para cada valor de window_size de 1 a 6
for window_size in range(1, 7):
    X = []
    y = []
    for i in range(len(scaled_data) - window_size):
        seq = scaled_data[i:i + window_size][:, :-1]
        label = scaled_data[i + window_size - 1][-1]
        X.append(seq)
        y.append(label)

    # Convertendo para arrays do JAX e armazenando no dicionário
    datasets[window_size] = {
        'X': jnp.array(X),
        'y': jnp.array(y)
    }

# %%
# Exemplo de acesso aos dados para window_size = 3
datasets[3]['X'].shape, datasets[3]['y'].shape
# Out:
# ((129, 3, 8), (129,))

# %%
window_size = 3

X = datasets[window_size]['X']
y = datasets[window_size]['y']
X.shape, y.shape
# Out:
# ((129, 3, 8), (129,))

# %%
X[0], y[0]
# Out:
# (Array([[0.        , 0.        , 0.        , 0.        , 0.        ,
#          0.        , 0.        , 1.        ],
#         [0.00239768, 0.00235357, 0.        , 0.        , 0.01052632,
#          0.00746082, 0.00894933, 0.9894737 ],
#         [0.00481577, 0.00464402, 0.        , 0.        , 0.03157895,
#          0.02252244, 0.02692939, 0.96842104]], dtype=float32),
#  Array(329., dtype=float32))

# %%
test_size = 24
val_size = 12
train_size = len(X) - test_size - val_size
train_size, val_size, test_size
# Out:
# (93, 12, 24)

# %%
X_train, y_train = X[:train_size], y[:train_size]
# X_val, y_val = X_train, y_train
X_val, y_val = X[train_size:train_size+val_size], y[train_size:train_size+val_size]
# X_test, y_test = X[train_size:], y[train_size:]
X_test, y_test = X[train_size+val_size:], y[train_size+val_size:]
# X_train, X_val, X_test = X, X, X
# y_train, y_val, y_test = y, y, y
X_trainval, y_trainval = X[:train_size+val_size], y[:train_size+val_size]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape, X_trainval.shape, y_trainval.shape
# Out:
# ((93, 3, 8), (93,), (12, 3, 8), (12,), (24, 3, 8), (24,), (105, 3, 8), (105,))

# %%
X_train[0], y_train[0]
# Out:
# (Array([[0.        , 0.        , 0.        , 0.        , 0.        ,
#          0.        , 0.        , 1.        ],
#         [0.00239768, 0.00235357, 0.        , 0.        , 0.01052632,
#          0.00746082, 0.00894933, 0.9894737 ],
#         [0.00481577, 0.00464402, 0.        , 0.        , 0.03157895,
#          0.02252244, 0.02692939, 0.96842104]], dtype=float32),
#  Array(329., dtype=float32))

# %%
npp=df["Np"].values[window_size:train_size+window_size]
gp=df["Gp"].values[window_size:train_size+window_size]/1000
wp=df["Wp"].values[window_size:train_size+window_size]
winj=df["Winj"].values[window_size:train_size+window_size]
bo=df["Bo"].values[window_size:train_size+window_size]
bg=df["Bg"].values[window_size:train_size+window_size]
rs=df["Rs"].values[window_size:train_size+window_size]
viso=df["Viso"].values[window_size:train_size+window_size]
visg=df["Visg"].values[window_size:train_size+window_size]
p=df["p"].values[window_size:train_size+window_size]
t=df['t'].values[window_size:train_size+window_size]

# npp=df["Np"].values
# gp=df["Gp"].values/1000
# wp=df["Wp"].values
# winj=df["Winj"].values
# bo=df["Bo"].values
# bg=df["Bg"].values
# rs=df["Rs"].values
# viso=df["Viso"].values
# visg=df["Visg"].values
# p=df["p"].values
# t=df['t'].values

# %%
p.shape, y_train.shape
# Out:
# ((93,), (93,))

# %%
# dt = jnp.diff(t)
# dt = jnp.insert(dt, 0, 1)
# qo = jnp.diff(npp)
# qo = jnp.insert(qo, 0, 0)
# qo = qo / dt
# qg = jnp.diff(gp)
# qg = jnp.insert(qg, 0, 0)
# qg = qg / dt
# qw = jnp.diff(wp)
# qw = jnp.insert(qw, 0, 0)
# qw = qw / dt
# qwi = jnp.diff(winj)
# qwi = jnp.insert(qwi, 0, 0)
# qwi = qwi / dt

# %%
## Parametros escalares (MODSI)
# phi = 0.13
# k = 77
m = 0.0
Bw = 1.0210
uw = 0.3
cf = 5.3E-05
pb = 210.03
bob = 1.414
co = 1.62E-04
cw = 4.76E-05
Swi = 0.17
Sor = 0.18
Sgc = 0.05

t0 = df['t'].values[0]
p0 = df["p"].values[0]
Rsi = df["Rs"].values[0]
boi = df["Bo"].values[0]
bgi = df["Bg"].values[0]

t0, p0, Rsi, boi, bgi
# Out:
# (0, 332, 113.06, 1.39424086, 0.003249477045853988)

# %%
# Definir a rede GRU usando Flax
class GRU(nn.Module):
    @nn.compact
    def __call__(self, x):
        input_shape = x[0].shape

        gru = nn.GRUCell(64)

        carry = gru.initialize_carry(jax.random.PRNGKey(0), input_shape)

        for i in range(x.shape[0]):
          if i < (x.shape[0] - 1):
            carry, _ = gru(carry, x[i])
          else:
            _, x = gru(carry, x[i])

        x = nn.Dense(1)(x)
        return x

# Initialize the random key
rng_key = random.PRNGKey(42)

class GRUnet(GRU):
    def setup(self):
        super().setup()
        self.N = self.param("N", jax.nn.initializers.constant(180.0), ())
        self.Wi = self.param("Wi", jax.nn.initializers.constant(100.0), ())
        self.J = self.param("J", jax.nn.initializers.constant(95.0), ())

# Define the Neural Network
model = GRUnet()

# Initialize the model parameters
rng_key, init_key = random.split(rng_key, 2)
dummy_input = jnp.zeros(X_train[0].shape)
params = model.init(init_key, dummy_input)

## Define the optimizer using Optax
# lr = 0.01
lr = optax.exponential_decay(init_value=1e-3,
                             transition_steps=3000,
                             decay_rate=0.98)
tx = optax.adam(learning_rate=lr)

# Create the training state
state = TrainState.create(
    apply_fn=lambda params_, x_: model.apply(params_, x_)[0],
    # apply_fn=model.apply,
    params=params,
    tx=tx)

# Print the model structure in a fancy way
print(model.tabulate(rng_key, dummy_input))
# Out:
#                                   GRUnet Summary
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ path         ┃ module  ┃ inputs        ┃ outputs       ┃ params                 ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │              │ GRUnet  │ float32[3,8]  │ float32[1]    │ J: float32[]           │
# │              │         │               │               │ N: float32[]           │
# │              │         │               │               │ Wi: float32[]          │
# │              │         │               │               │                        │
# │              │         │               │               │ 3 (12 B)               │
# ├──────────────┼─────────┼───────────────┼───────────────┼────────────────────────┤
# │ GRUCell_0    │ GRUCell │ - float32[64] │ - float32[64] │                        │
# │              │         │ - float32[8]  │ - float32[64] │                        │
# ├──────────────┼─────────┼───────────────┼───────────────┼────────────────────────┤
# │ GRUCell_0/ir │ Dense   │ float32[8]    │ float32[64]   │ bias: float32[64]      │
# │              │         │               │               │ kernel: float32[8,64]  │
# │              │         │               │               │                        │
# │              │         │               │               │ 576 (2.3 KB)           │
# ├──────────────┼─────────┼───────────────┼───────────────┼────────────────────────┤
# │ GRUCell_0/hr │ Dense   │ float32[64]   │ float32[64]   │ kernel: float32[64,64] │
# │              │         │               │               │                        │
# │              │         │               │               │ 4,096 (16.4 KB)        │
# ├──────────────┼─────────┼───────────────┼───────────────┼────────────────────────┤
# │ GRUCell_0/iz │ Dense   │ float32[8]    │ float32[64]   │ bias: float32[64]      │
# │              │         │               │               │ kernel: float32[8,64]  │
# │              │         │               │               │                        │
# │              │         │               │               │ 576 (2.3 KB)           │
# ├──────────────┼─────────┼───────────────┼───────────────┼────────────────────────┤
# │ GRUCell_0/hz │ Dense   │ float32[64]   │ float32[64]   │ kernel: float32[64,64] │
# │              │         │               │               │                        │
# │              │         │               │               │ 4,096 (16.4 KB)        │
# ├──────────────┼─────────┼───────────────┼───────────────┼────────────────────────┤
# │ GRUCell_0/in │ Dense   │ float32[8]    │ float32[64]   │ bias: float32[64]      │
# │              │         │               │               │ kernel: float32[8,64]  │
# │              │         │               │               │                        │
# │              │         │               │               │ 576 (2.3 KB)           │
# ├──────────────┼─────────┼───────────────┼───────────────┼────────────────────────┤
# │ GRUCell_0/hn │ Dense   │ float32[64]   │ float32[64]   │ bias: float32[64]      │
# │              │         │               │               │ kernel: float32[64,64] │
# │              │         │               │               │                        │
# │              │         │               │               │ 4,160 (16.6 KB)        │
# ├──────────────┼─────────┼───────────────┼───────────────┼────────────────────────┤
# │ Dense_0      │ Dense   │ float32[64]   │ float32[1]    │ bias: float32[1]       │
# │              │         │               │               │ kernel: float32[64,1]  │
# │              │         │               │               │                        │
# │              │         │               │               │ 65 (260 B)             │
# ├──────────────┼─────────┼───────────────┼───────────────┼────────────────────────┤
# │              │         │               │         Total │ 14,148 (56.6 KB)       │
# └──────────────┴─────────┴───────────────┴───────────────┴────────────────────────┘
#
#                         Total Parameters: 14,148 (56.6 KB)

# %%
# Imprimindo os parametros a serem ajustados
state.params['params']['N'], state.params['params']['Wi'], state.params['params']['J']
# Out:
# (Array(180., dtype=float32),
#  Array(100., dtype=float32),
#  Array(95., dtype=float32))

# %%
# Avaliando o modelo para um único vetor de entrada
x_single = X_train[0]
u_pred = state.apply_fn(params, x_single)
print(f"The solution for u(x={x_single} = {u_pred}")

# Avaliando a rede neural antes do treinamento considerando todo o histórico
u_pred = vmap(state.apply_fn, (None, 0))(state.params, X)

fig, ax = plt.subplots(1,1, figsize=(10,10/1.618))

ax.scatter(df['t'].values, df["p"].values, label=r'$u_{meas}$', color='black')
ax.plot(df["t"].values[window_size:], u_pred, label=r'$u_{pred}$', color='red')

ax.legend()
ax.set_title('Previsão antes do ajuste do modelo')
# Out:
# The solution for u(x=[[0.         0.         0.         0.         0.         0.
#   0.         1.        ]
#  [0.00239768 0.00235357 0.         0.         0.01052632 0.00746082
#   0.00894933 0.9894737 ]
#  [0.00481577 0.00464402 0.         0.         0.03157895 0.02252244
#   0.02692939 0.96842104]] = -0.5449830293655396
# Text(0.5, 1.0, 'Previsão antes do ajuste do modelo')

# %%
# Definir loss function
@jit
def train_step(state, batch):
    def phy_residual_fn(params, u):
        # Aplicar limites nos parâmetros
        N = jnp.clip(params['params']['N'], 0.0, 300.0)  # Limita N entre 0 e 300
        Wi = jnp.clip(params['params']['Wi'], 100.0, 1000.0)  # Limita Wi entre 100 e 1000
        J = jnp.clip(params['params']['J'], 1.0, 100.0)  # Limita J entre 1 e 100

        #EBM
        rp = gp  / jnp.where(npp != 0, npp, 1.0) * 1000
        F = npp * (bo + (rp-rs) * bg) + (wp - winj) * Bw
        Eo = bo - boi + (Rsi - rs) * bg
        Eg = boi * ((bg / bgi) - 1)
        Efw = (1 + m) * boi * ((cf + cw * Swi)/(1 - Swi)) * (p0 - u)
        We_EBM = F - (N * 10**6) * (Eo + m * Eg + Efw)

        #Aquif
        Wei = (cf + cw) * Wi * p0 * 10**6
        Wen = jnp.zeros(len(t))
        dt = jnp.diff(t)
        dt = jnp.insert(dt, 0, t[0])
        pa_med = jnp.zeros(len(t))
        pa_med = pa_med.at[0].set(p0)
        for i in range(1,len(t)):
          pa_med = pa_med.at[i-1].set(p0 *(1 - (Wen[i-1] / Wei)))
          Wen = Wen.at[i].set(Wen[i-1] + (Wei / p0) * (pa_med[i-1] - u[i]) * (1 - jnp.exp(-J * p0 * dt[i] / Wei)))

        res = (We_EBM - Wen) / 10**6
        # res = 0.0
        return res

    def loss_fn(params, batch):
        u_pred = vmap(state.apply_fn, (None, 0))(params, batch['x'])
        res_pred = phy_residual_fn(params, u_pred)
        phy_loss = jnp.mean(res_pred ** 2) ** 0.5
        data_loss = jnp.mean(jnp.square(u_pred - batch['u']))
        total_loss = 10.0 * data_loss + 1.0 * phy_loss
        return total_loss, {
            "total_loss": total_loss,
            "data_loss": data_loss,
            "phy_loss": phy_loss,
        }

    # Compute the loss and its grads w.r.t. the model parameters
    (_, loss_components), grads = value_and_grad(loss_fn, has_aux=True)(
        state.params, batch
    )
    state = state.apply_gradients(grads=grads)
    return loss_components, state

# Definir evaluation function
@jit
def eval_step(state, batch):
    def eval_error(params, batch):
        u_pred = vmap(state.apply_fn, (None, 0))(params, batch['x'])
        # return jnp.linalg.norm(x=(u_pred - batch['u']), ord=2) / jnp.linalg.norm(x=batch['u'], ord=2)
        return jnp.mean(jnp.square(u_pred - batch['u']))
    return eval_error(state.params, batch)

# %%
## TREINAMENTO ##

# Criar logs de treinamento
total_loss_log = []
data_loss_log = []
phy_loss_log = []
epoch_log = []
error_log = []
N_log = []
Wi_log = []
J_log = []

# Criar batches de treinamento e validação
train_batch = {'x': X_train, 'u': y_train}
eval_batch = {'x': X_val, 'u': y_val}

# Criar variável para armazenar o menor erro de validação e o estado correspondente
best_error = float('inf')
best_state = None

# Executar o treinamento da rede neural
epochs = 50_000

for epoch in range(epochs):
  loss, state = train_step(state, train_batch)
  if epoch%1000 == 0:
    epoch_log.append(epoch)
    N_est = state.params["params"]["N"]
    Wi_est = state.params["params"]["Wi"]
    J_est = state.params["params"]["J"]
    total_loss_log.append(loss['total_loss'])
    data_loss_log.append(loss['data_loss'])
    phy_loss_log.append(loss['phy_loss'])
    eval_error = eval_step(state, eval_batch)
    error_log.append(eval_error)
    N_log.append(N_est)
    Wi_log.append(Wi_est)
    J_log.append(J_est)
    print(f"Epoch: {epoch} -- Total Loss: {loss['total_loss']:0.6f}  -- Data Loss: {loss['data_loss']:0.6f} -- Physics Loss: {loss['phy_loss']:0.6f} -- Error: {eval_error:0.6f} -- N: {N_est:0.2f} -- Wi: {Wi_est:0.2f} -- J: {J_est:0.2f}")

    # Salvar o estado do modelo com menor erro
    if (epoch > 10_000) and (eval_error < best_error):
        best_error = eval_error
        best_state = state
# Out:
# Epoch: 0 -- Total Loss: 705368.250000  -- Data Loss: 70536.085938 -- Physics Loss: 7.343815 -- Error: 79000.812500 -- N: 180.00 -- Wi: 100.00 -- J: 95.00
# Epoch: 1000 -- Total Loss: 380013.250000  -- Data Loss: 38000.792969 -- Physics Loss: 5.322737 -- Error: 43920.625000 -- N: 179.04 -- Wi: 99.99 -- J: 94.04
# Epoch: 2000 -- Total Loss: 200243.281250  -- Data Loss: 20023.947266 -- Physics Loss: 3.801867 -- Error: 24165.195312 -- N: 178.15 -- Wi: 99.99 -- J: 93.13
# Epoch: 3000 -- Total Loss: 92245.281250  -- Data Loss: 9224.275391 -- Physics Loss: 2.522313 -- Error: 11829.681641 -- N: 177.31 -- Wi: 99.99 -- J: 92.25
# Epoch: 4000 -- Total Loss: 35721.875000  -- Data Loss: 3572.034180 -- Physics Loss: 1.529478 -- Error: 4901.487793 -- N: 176.54 -- Wi: 99.99 -- J: 91.38
# Epoch: 5000 -- Total Loss: 13106.995117  -- Data Loss: 1310.604004 -- Physics Loss: 0.955462 -- Error: 1685.304688 -- N: 175.97 -- Wi: 99.99 -- J: 90.52
# Epoch: 6000 -- Total Loss: 7648.426758  -- Data Loss: 764.759155 -- Physics Loss: 0.834757 -- Error: 574.535767 -- N: 175.92 -- Wi: 99.99 -- J: 89.76
# Epoch: 7000 -- Total Loss: 7120.575195  -- Data Loss: 711.972473 -- Physics Loss: 0.850466 -- Error: 314.107391 -- N: 176.53 -- Wi: 99.99 -- J: 89.07
# Epoch: 8000 -- Total Loss: 2548.793701  -- Data Loss: 254.836487 -- Physics Loss: 0.428777 -- Error: 33.099377 -- N: 177.20 -- Wi: 99.99 -- J: 88.29
# Epoch: 9000 -- Total Loss: 738.781128  -- Data Loss: 73.848129 -- Physics Loss: 0.299825 -- Error: 6.656961 -- N: 178.21 -- Wi: 99.99 -- J: 87.94
# Epoch: 10000 -- Total Loss: 179.837326  -- Data Loss: 17.958227 -- Physics Loss: 0.255046 -- Error: 0.279566 -- N: 179.33 -- Wi: 99.99 -- J: 88.49
# Epoch: 11000 -- Total Loss: 38.168365  -- Data Loss: 3.792832 -- Physics Loss: 0.240046 -- Error: 1.912182 -- N: 180.33 -- Wi: 99.99 -- J: 89.52
# Epoch: 12000 -- Total Loss: 7.422914  -- Data Loss: 0.719105 -- Physics Loss: 0.231864 -- Error: 1.757693 -- N: 181.22 -- Wi: 99.99 -- J: 90.51
# Epoch: 13000 -- Total Loss: 1.631467  -- Data Loss: 0.140574 -- Physics Loss: 0.225725 -- Error: 0.938640 -- N: 182.06 -- Wi: 99.99 -- J: 91.44
# Epoch: 14000 -- Total Loss: 0.568479  -- Data Loss: 0.034906 -- Physics Loss: 0.219414 -- Error: 0.271184 -- N: 182.86 -- Wi: 99.99 -- J: 92.33
# Epoch: 15000 -- Total Loss: 0.380196  -- Data Loss: 0.016560 -- Physics Loss: 0.214594 -- Error: 0.035719 -- N: 183.62 -- Wi: 99.99 -- J: 93.19
# Epoch: 16000 -- Total Loss: 0.327807  -- Data Loss: 0.011698 -- Physics Loss: 0.210822 -- Error: 0.004688 -- N: 184.34 -- Wi: 99.99 -- J: 94.04
# Epoch: 17000 -- Total Loss: 0.303895  -- Data Loss: 0.009578 -- Physics Loss: 0.208111 -- Error: 0.014556 -- N: 185.00 -- Wi: 99.99 -- J: 94.88
# Epoch: 18000 -- Total Loss: 0.285769  -- Data Loss: 0.007943 -- Physics Loss: 0.206341 -- Error: 0.022766 -- N: 185.59 -- Wi: 99.99 -- J: 95.71
# Epoch: 19000 -- Total Loss: 0.270311  -- Data Loss: 0.006497 -- Physics Loss: 0.205345 -- Error: 0.012682 -- N: 186.09 -- Wi: 99.99 -- J: 96.54
# Epoch: 20000 -- Total Loss: 0.281120  -- Data Loss: 0.007614 -- Physics Loss: 0.204983 -- Error: 0.010880 -- N: 186.45 -- Wi: 99.99 -- J: 97.36
# Epoch: 21000 -- Total Loss: 0.271491  -- Data Loss: 0.006666 -- Physics Loss: 0.204835 -- Error: 0.007715 -- N: 186.65 -- Wi: 99.99 -- J: 98.18
# Epoch: 22000 -- Total Loss: 0.243597  -- Data Loss: 0.003910 -- Physics Loss: 0.204498 -- Error: 0.022955 -- N: 186.71 -- Wi: 99.99 -- J: 99.01
# Epoch: 23000 -- Total Loss: 0.235698  -- Data Loss: 0.003132 -- Physics Loss: 0.204377 -- Error: 0.041829 -- N: 186.71 -- Wi: 99.99 -- J: 99.84
# Epoch: 24000 -- Total Loss: 0.229628  -- Data Loss: 0.002528 -- Physics Loss: 0.204347 -- Error: 0.063034 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 25000 -- Total Loss: 0.232564  -- Data Loss: 0.002834 -- Physics Loss: 0.204222 -- Error: 0.108502 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 26000 -- Total Loss: 0.224974  -- Data Loss: 0.002068 -- Physics Loss: 0.204293 -- Error: 0.128418 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 27000 -- Total Loss: 0.217214  -- Data Loss: 0.001287 -- Physics Loss: 0.204345 -- Error: 0.142618 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 28000 -- Total Loss: 0.217986  -- Data Loss: 0.001359 -- Physics Loss: 0.204399 -- Error: 0.146699 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 29000 -- Total Loss: 0.213190  -- Data Loss: 0.000886 -- Physics Loss: 0.204335 -- Error: 0.167954 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 30000 -- Total Loss: 0.211850  -- Data Loss: 0.000752 -- Physics Loss: 0.204335 -- Error: 0.166979 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 31000 -- Total Loss: 0.210829  -- Data Loss: 0.000650 -- Physics Loss: 0.204333 -- Error: 0.164418 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 32000 -- Total Loss: 0.209974  -- Data Loss: 0.000564 -- Physics Loss: 0.204333 -- Error: 0.155287 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 33000 -- Total Loss: 0.209840  -- Data Loss: 0.000548 -- Physics Loss: 0.204361 -- Error: 0.139701 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 34000 -- Total Loss: 0.208701  -- Data Loss: 0.000437 -- Physics Loss: 0.204332 -- Error: 0.134229 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 35000 -- Total Loss: 0.208230  -- Data Loss: 0.000390 -- Physics Loss: 0.204332 -- Error: 0.126126 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 36000 -- Total Loss: 0.207854  -- Data Loss: 0.000352 -- Physics Loss: 0.204330 -- Error: 0.123636 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 37000 -- Total Loss: 0.207446  -- Data Loss: 0.000312 -- Physics Loss: 0.204330 -- Error: 0.114619 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 38000 -- Total Loss: 0.207102  -- Data Loss: 0.000277 -- Physics Loss: 0.204330 -- Error: 0.104991 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 39000 -- Total Loss: 0.206842  -- Data Loss: 0.000251 -- Physics Loss: 0.204329 -- Error: 0.098679 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 40000 -- Total Loss: 0.206574  -- Data Loss: 0.000224 -- Physics Loss: 0.204330 -- Error: 0.090513 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 41000 -- Total Loss: 0.206387  -- Data Loss: 0.000206 -- Physics Loss: 0.204329 -- Error: 0.086266 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 42000 -- Total Loss: 0.206196  -- Data Loss: 0.000186 -- Physics Loss: 0.204331 -- Error: 0.079977 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 43000 -- Total Loss: 0.206063  -- Data Loss: 0.000173 -- Physics Loss: 0.204329 -- Error: 0.076192 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 44000 -- Total Loss: 0.206453  -- Data Loss: 0.000212 -- Physics Loss: 0.204336 -- Error: 0.069589 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 45000 -- Total Loss: 0.205850  -- Data Loss: 0.000152 -- Physics Loss: 0.204330 -- Error: 0.067061 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 46000 -- Total Loss: 0.205762  -- Data Loss: 0.000143 -- Physics Loss: 0.204331 -- Error: 0.061463 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 47000 -- Total Loss: 0.205678  -- Data Loss: 0.000135 -- Physics Loss: 0.204329 -- Error: 0.056647 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 48000 -- Total Loss: 0.205643  -- Data Loss: 0.000131 -- Physics Loss: 0.204329 -- Error: 0.053826 -- N: 186.71 -- Wi: 99.99 -- J: 100.01
# Epoch: 49000 -- Total Loss: 0.205566  -- Data Loss: 0.000124 -- Physics Loss: 0.204328 -- Error: 0.047979 -- N: 186.71 -- Wi: 99.99 -- J: 100.01

# %%
# Plot training & validation loss values
fig, axs = plt.subplots(1, 2, figsize=(16, 16 / 1.618))

axs[0].plot(epoch_log, total_loss_log, label="Total Loss")
axs[0].plot(epoch_log, data_loss_log, label="Data Loss")
axs[0].plot(epoch_log, phy_loss_log, label="Physics Loss")
axs[0].plot(epoch_log, error_log, label="Error")
axs[0].set_yscale("log")
axs[0].legend()

axs[1].plot(epoch_log, N_log, label="N_est")
axs[1].plot(epoch_log, Wi_log, label="Wi_est")
axs[1].plot(epoch_log, J_log, label="J_est")
axs[1].legend()

# %%
# Imprimindo os parametros ajustados
best_state.params['params']['N'], best_state.params['params']['Wi'], best_state.params['params']['J']
# Out:
# (Array(184.33589, dtype=float32),
#  Array(99.99402, dtype=float32),
#  Array(94.043884, dtype=float32))

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Predict using the trained model
predictions = vmap(best_state.apply_fn, (None, 0))(best_state.params, X_test)

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MAE): 1.4208298
# Mean Squared Error (MSE): 5.05541
# Root Mean Squared Error (RMSE): 2.2484238

# %%
# Avaliando a rede neural depois do treinamento considerando o teste

fig, ax = plt.subplots(1,1, figsize=(10,10/1.618))

ax.scatter(jnp.arange(0, len(y_test), 1), y_test, label=r'$u_{meas}$', color='black')
ax.plot(jnp.arange(0, len(y_test), 1), predictions, label=r'$u_{pred}$', color='red')

ax.legend()
ax.set_title('Previsão depois do ajuste do modelo')
# Out:
# Text(0.5, 1.0, 'Previsão depois do ajuste do modelo')

# %%
# Avaliando a rede neural depois do treinamento considerando todo o histórico
u_pred = vmap(best_state.apply_fn, (None, 0))(best_state.params, X)

fig, ax = plt.subplots(1,1, figsize=(10,10/1.618))

ax.scatter(df['t'].values, df["p"].values, label=r'$u_{meas}$', color='black')
ax.plot(df["t"].values[window_size:], u_pred, label=r'$u_{pred}$', color='red')

ax.legend()
ax.set_title('Previsão depois do ajuste do modelo')
# Out:
# Text(0.5, 1.0, 'Previsão depois do ajuste do modelo')

# %%
import itertools

# Hiperparâmetros para o grid search
window_sizes = [1, 2, 3]
layer_size_options = [32, 64, 128]
num_epochs_options = [25_000, 50_000]

# Criando todas as combinações possíveis
combinations = list(itertools.product(
        window_sizes, layer_size_options, num_epochs_options))

# Criando o DataFrame
df_exp = pd.DataFrame(combinations, columns=['window_size', 'layer_size', 'num_epochs'])

# Cria coluna para os resultados MAE
df_exp['MAE'] = None

df_exp
# Out:
#     window_size  layer_size  num_epochs   MAE
# 0             1          32       25000  None
# 1             1          32       50000  None
# 2             1          64       25000  None
# 3             1          64       50000  None
# 4             1         128       25000  None
# 5             1         128       50000  None
# 6             2          32       25000  None
# 7             2          32       50000  None
# 8             2          64       25000  None
# 9             2          64       50000  None
# 10            2         128       25000  None
# 11            2         128       50000  None
# 12            3          32       25000  None
# 13            3          32       50000  None
# 14            3          64       25000  None
# 15            3          64       50000  None
# 16            3         128       25000  None
# 17            3         128       50000  None

# %%
import time

# Estrutura para armazenar o melhor resultado e configuração
best_result = {
    "error": float('inf'),
    "params": None,
    "model_state": None,
    "index": None,
}

inicio_fc = time.time()

# Loop para o grid search
for i in range(len(combinations)):
    window_size, layer_size, num_epochs = combinations[i]

    # Preparação dos dados para o `window_size` atual
    X = datasets[window_size]['X']
    y = datasets[window_size]['y']

    # Divisão dos dados em treino, validação e teste
    test_size = 24
    val_size = 12
    train_size = len(X) - test_size - val_size
    X_train, y_train = X[:train_size], y[:train_size]
    X_val, y_val = X[train_size:train_size + val_size], y[train_size:train_size + val_size]
    X_test, y_test = X[train_size + val_size:], y[train_size + val_size:]

    npp=df["Np"].values[window_size:train_size+window_size]
    gp=df["Gp"].values[window_size:train_size+window_size]/1000
    wp=df["Wp"].values[window_size:train_size+window_size]
    winj=df["Winj"].values[window_size:train_size+window_size]
    bo=df["Bo"].values[window_size:train_size+window_size]
    bg=df["Bg"].values[window_size:train_size+window_size]
    rs=df["Rs"].values[window_size:train_size+window_size]
    viso=df["Viso"].values[window_size:train_size+window_size]
    visg=df["Visg"].values[window_size:train_size+window_size]
    p=df["p"].values[window_size:train_size+window_size]
    t=df['t'].values[window_size:train_size+window_size]

    # Definir a rede GRU dinâmica usando Flax
    class GRU(nn.Module):
      @nn.compact
      def __call__(self, x):
          input_shape = x[0].shape

          gru = nn.GRUCell(layer_size)

          carry = gru.initialize_carry(jax.random.PRNGKey(0), input_shape)

          for i in range(x.shape[0]):
            if i < (x.shape[0] - 1):
              carry, _ = gru(carry, x[i])
            else:
              _, x = gru(carry, x[i])

          x = nn.Dense(1)(x)
          return x

    # Initialize the random key
    rng_key = random.PRNGKey(42)

    class GRUnet(GRU):
        def setup(self):
            super().setup()
            self.N = self.param("N", jax.nn.initializers.constant(180.0), ())
            self.Wi = self.param("Wi", jax.nn.initializers.constant(100.0), ())
            self.J = self.param("J", jax.nn.initializers.constant(95.0), ())

    # Define the Neural Network
    model = GRUnet()

    # Initialize the model parameters
    rng_key, init_key = random.split(rng_key, 2)
    dummy_input = jnp.zeros(X_train[0].shape)  # Assumindo que X_train já está definido
    params = model.init(init_key, dummy_input)

    # Definir o otimizador
    lr = optax.exponential_decay(init_value=1e-3, transition_steps=3000, decay_rate=0.98)
    tx = optax.adam(learning_rate=lr)

    # Create the training state
    state = TrainState.create(
      apply_fn=lambda params_, x_: model.apply(params_, x_)[0],
      # apply_fn=model.apply,
      params=params,
      tx=tx)

    # Criar logs de treinamento
    total_loss_log = []
    data_loss_log = []
    phy_loss_log = []
    epoch_log = []
    error_log = []
    N_log = []
    Wi_log = []
    J_log = []

    # Configurar batches de treino e validação
    train_batch = {'x': X_train, 'u': y_train}
    eval_batch = {'x': X_val, 'u': y_val}

    # Variáveis de controle de melhor erro
    best_error = float('inf')
    best_state = None

    # Treinamento para o número de épocas especificado
    for epoch in range(num_epochs):
        loss, state = train_step(state, train_batch)

        if epoch % 1000 == 0:
            epoch_log.append(epoch)
            N_est = state.params["params"]["N"]
            Wi_est = state.params["params"]["Wi"]
            J_est = state.params["params"]["J"]
            total_loss_log.append(loss['total_loss'])
            data_loss_log.append(loss['data_loss'])
            phy_loss_log.append(loss['phy_loss'])
            eval_error = eval_step(state, eval_batch)
            error_log.append(eval_error)
            N_log.append(N_est)
            Wi_log.append(Wi_est)
            J_log.append(J_est)
            # print(f"Epoch: {epoch} -- Total Loss: {loss['total_loss']:0.6f}  -- Data Loss: {loss['data_loss']:0.6f} -- Physics Loss: {loss['phy_loss']:0.6f} -- Error: {eval_error:0.6f} -- N: {N_est:0.2f} -- Wi: {Wi_est:0.2f} -- J: {J_est:0.2f}")

            if (epoch > 10_000) and (eval_error < best_error):
                best_error = eval_error
                best_state = state

    # Teste final com o melhor estado encontrado nesta combinação
    predictions = vmap(best_state.apply_fn, (None, 0))(best_state.params, X_test)
    mae = mean_absolute_error(y_test, predictions)
    df_exp.loc[i, 'MAE'] = mae

    # Verificar se esta combinação é a melhor até agora
    if mae < best_result["error"]:
        best_result["error"] = mae
        best_result["params"] = {
            "window_size": window_size,
            "layer_size": layer_size,
            "num_epochs": num_epochs
        }
        best_result["model_state"] = best_state
        best_result["index"] = i

    print(f"Rodada {i+1}/{len(combinations)}: window_size={window_size}, layer_size={layer_size}, "
          f"num_epochs={num_epochs} -- MAE: {mae:.02f}")

fim_fc = time.time()
tempo_fc = fim_fc - inicio_fc
print(f"\nTempo de execução: {tempo_fc:0.2f} segundos")
# Out:
# Rodada 1/18: window_size=1, layer_size=32, num_epochs=25000 -- MAE: 6.56
# Rodada 2/18: window_size=1, layer_size=32, num_epochs=50000 -- MAE: 4.53
# Rodada 3/18: window_size=1, layer_size=64, num_epochs=25000 -- MAE: 4.65
# Rodada 4/18: window_size=1, layer_size=64, num_epochs=50000 -- MAE: 3.38
# Rodada 5/18: window_size=1, layer_size=128, num_epochs=25000 -- MAE: 3.02
# Rodada 6/18: window_size=1, layer_size=128, num_epochs=50000 -- MAE: 2.14
# Rodada 7/18: window_size=2, layer_size=32, num_epochs=25000 -- MAE: 5.26
# Rodada 8/18: window_size=2, layer_size=32, num_epochs=50000 -- MAE: 3.83
# Rodada 9/18: window_size=2, layer_size=64, num_epochs=25000 -- MAE: 3.32
# Rodada 10/18: window_size=2, layer_size=64, num_epochs=50000 -- MAE: 5.93
# Rodada 11/18: window_size=2, layer_size=128, num_epochs=25000 -- MAE: 1.23
# Rodada 12/18: window_size=2, layer_size=128, num_epochs=50000 -- MAE: 1.00
# Rodada 13/18: window_size=3, layer_size=32, num_epochs=25000 -- MAE: 4.06
# Rodada 14/18: window_size=3, layer_size=32, num_epochs=50000 -- MAE: 3.26
# Rodada 15/18: window_size=3, layer_size=64, num_epochs=25000 -- MAE: 1.42
# Rodada 16/18: window_size=3, layer_size=64, num_epochs=50000 -- MAE: 1.42
# Rodada 17/18: window_size=3, layer_size=128, num_epochs=25000 -- MAE: 0.44
# Rodada 18/18: window_size=3, layer_size=128, num_epochs=50000 -- MAE: 0.44
#
# Tempo de execução: 1960.59 segundos

# %%
df_exp.to_excel('/content/drive/MyDrive/UNISIM/results_pinn_gru.xlsx', sheet_name='results_gru', index=False)
df_exp
# Out:
#     window_size  layer_size  num_epochs       MAE
# 0             1          32       25000  6.559814
# 1             1          32       50000  4.531166
# 2             1          64       25000  4.646528
# 3             1          64       50000   3.38157
# 4             1         128       25000  3.024026
# 5             1         128       50000  2.143274
# 6             2          32       25000  5.256711
# 7             2          32       50000  3.832568
# 8             2          64       25000  3.316603
# 9             2          64       50000  5.927174
# 10            2         128       25000  1.226613
# 11            2         128       50000  1.001209
# 12            3          32       25000  4.063873
# 13            3          32       50000  3.258794
# 14            3          64       25000   1.42083
# 15            3          64       50000   1.42083
# 16            3         128       25000  0.441479
# 17            3         128       50000  0.441479

# %%
best_result["model_state"].params['params']['N'], best_result["model_state"].params['params']['Wi'], best_result["model_state"].params['params']['J']
# Out:
# (Array(183.93631, dtype=float32),
#  Array(99.99402, dtype=float32),
#  Array(95.15345, dtype=float32))

# %%
best_result["error"], best_result["params"]
# Out:
# (0.44147873, {'window_size': 3, 'layer_size': 128, 'num_epochs': 25000})

# %%
window_size, layer_size, num_epochs = combinations[best_result["index"]]
window_size, layer_size, num_epochs
# Out:
# (3, 128, 25000)

# %%
# Preparação dos dados para o `window_size` atual
X = datasets[window_size]['X']
y = datasets[window_size]['y']

# Divisão dos dados em treino, validação e teste
test_size = 24
train_size = len(X) - test_size
X_train, y_train = X[:train_size], y[:train_size]
X_val, y_val = X_train, y_train
X_test, y_test = X[train_size:], y[train_size:]

npp=df["Np"].values[window_size:train_size+window_size]
gp=df["Gp"].values[window_size:train_size+window_size]/1000
wp=df["Wp"].values[window_size:train_size+window_size]
winj=df["Winj"].values[window_size:train_size+window_size]
bo=df["Bo"].values[window_size:train_size+window_size]
bg=df["Bg"].values[window_size:train_size+window_size]
rs=df["Rs"].values[window_size:train_size+window_size]
viso=df["Viso"].values[window_size:train_size+window_size]
visg=df["Visg"].values[window_size:train_size+window_size]
p=df["p"].values[window_size:train_size+window_size]
t=df['t'].values[window_size:train_size+window_size]

# %%
## TREINAMENTO ##

# Criar logs de treinamento
total_loss_log = []
data_loss_log = []
phy_loss_log = []
epoch_log = []
error_log = []
N_log = []
Wi_log = []
J_log = []

# Criar batches de treinamento e validação
train_batch = {'x': X_train, 'u': y_train}
eval_batch = {'x': X_val, 'u': y_val}

# Criar variável para armazenar o menor erro de validação e o estado correspondente
best_error = float('inf')
best_state = None
state = best_result["model_state"]

# Executar o treinamento da rede neural
for epoch in range(num_epochs):
  loss, state = train_step(state, train_batch)
  if epoch%1000 == 0:
    epoch_log.append(epoch)
    N_est = state.params["params"]["N"]
    Wi_est = state.params["params"]["Wi"]
    J_est = state.params["params"]["J"]
    total_loss_log.append(loss['total_loss'])
    data_loss_log.append(loss['data_loss'])
    phy_loss_log.append(loss['phy_loss'])
    eval_error = eval_step(state, eval_batch)
    error_log.append(eval_error)
    N_log.append(N_est)
    Wi_log.append(Wi_est)
    J_log.append(J_est)
    print(f"Epoch: {epoch} -- Total Loss: {loss['total_loss']:0.6f}  -- Data Loss: {loss['data_loss']:0.6f} -- Physics Loss: {loss['phy_loss']:0.6f} -- Error: {eval_error:0.6f} -- N: {N_est:0.2f} -- Wi: {Wi_est:0.2f} -- J: {J_est:0.2f}")

    # Salvar o estado do modelo com menor erro
    if (epoch > 10_000) and (eval_error < best_error):
        best_error = eval_error
        best_state = state
# Out:
# Epoch: 0 -- Total Loss: 0.787482  -- Data Loss: 0.056589 -- Physics Loss: 0.221591 -- Error: 0.098666 -- N: 183.94 -- Wi: 99.99 -- J: 95.15
# Epoch: 1000 -- Total Loss: 0.403070  -- Data Loss: 0.018401 -- Physics Loss: 0.219063 -- Error: 0.018394 -- N: 184.31 -- Wi: 99.99 -- J: 96.01
# Epoch: 2000 -- Total Loss: 0.348028  -- Data Loss: 0.012976 -- Physics Loss: 0.218272 -- Error: 0.013040 -- N: 184.70 -- Wi: 99.99 -- J: 96.88
# Epoch: 3000 -- Total Loss: 0.308686  -- Data Loss: 0.009083 -- Physics Loss: 0.217861 -- Error: 0.009079 -- N: 185.04 -- Wi: 99.99 -- J: 97.75
# Epoch: 4000 -- Total Loss: 0.285453  -- Data Loss: 0.006784 -- Physics Loss: 0.217618 -- Error: 0.006783 -- N: 185.26 -- Wi: 99.99 -- J: 98.61
# Epoch: 5000 -- Total Loss: 0.271369  -- Data Loss: 0.005394 -- Physics Loss: 0.217432 -- Error: 0.005393 -- N: 185.35 -- Wi: 99.99 -- J: 99.48
# Epoch: 6000 -- Total Loss: 0.261838  -- Data Loss: 0.004452 -- Physics Loss: 0.217315 -- Error: 0.004457 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 7000 -- Total Loss: 0.260431  -- Data Loss: 0.004322 -- Physics Loss: 0.217211 -- Error: 0.004215 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 8000 -- Total Loss: 0.252065  -- Data Loss: 0.003481 -- Physics Loss: 0.217258 -- Error: 0.003552 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 9000 -- Total Loss: 0.262246  -- Data Loss: 0.004517 -- Physics Loss: 0.217071 -- Error: 0.005200 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 10000 -- Total Loss: 0.241330  -- Data Loss: 0.002404 -- Physics Loss: 0.217292 -- Error: 0.002396 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 11000 -- Total Loss: 0.236046  -- Data Loss: 0.001874 -- Physics Loss: 0.217309 -- Error: 0.001870 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 12000 -- Total Loss: 0.230854  -- Data Loss: 0.001355 -- Physics Loss: 0.217307 -- Error: 0.001354 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 13000 -- Total Loss: 0.228872  -- Data Loss: 0.001156 -- Physics Loss: 0.217309 -- Error: 0.001156 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 14000 -- Total Loss: 0.227702  -- Data Loss: 0.001039 -- Physics Loss: 0.217316 -- Error: 0.001040 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 15000 -- Total Loss: 0.227303  -- Data Loss: 0.000999 -- Physics Loss: 0.217311 -- Error: 0.001001 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 16000 -- Total Loss: 0.227095  -- Data Loss: 0.000982 -- Physics Loss: 0.217274 -- Error: 0.000973 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 17000 -- Total Loss: 0.283438  -- Data Loss: 0.006646 -- Physics Loss: 0.216980 -- Error: 0.010302 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 18000 -- Total Loss: 0.226500  -- Data Loss: 0.000922 -- Physics Loss: 0.217275 -- Error: 0.001509 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 19000 -- Total Loss: 0.239877  -- Data Loss: 0.002278 -- Physics Loss: 0.217092 -- Error: 0.002169 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 20000 -- Total Loss: 0.227090  -- Data Loss: 0.000969 -- Physics Loss: 0.217400 -- Error: 0.000831 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 21000 -- Total Loss: 0.224065  -- Data Loss: 0.000676 -- Physics Loss: 0.217307 -- Error: 0.000691 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 22000 -- Total Loss: 0.391068  -- Data Loss: 0.017298 -- Physics Loss: 0.218091 -- Error: 0.022121 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 23000 -- Total Loss: 0.223413  -- Data Loss: 0.000607 -- Physics Loss: 0.217339 -- Error: 0.000643 -- N: 185.36 -- Wi: 99.99 -- J: 100.01
# Epoch: 24000 -- Total Loss: 0.223411  -- Data Loss: 0.000610 -- Physics Loss: 0.217315 -- Error: 0.000611 -- N: 185.36 -- Wi: 99.99 -- J: 100.01

# %%
# Plot training & validation loss values
fig, axs = plt.subplots(1, 2, figsize=(16, 16 / 1.618))

axs[0].plot(epoch_log, total_loss_log, label="Total Loss")
axs[0].plot(epoch_log, data_loss_log, label="Data Loss")
axs[0].plot(epoch_log, phy_loss_log, label="Physics Loss")
axs[0].plot(epoch_log, error_log, label="Error")
axs[0].set_yscale("log")
axs[0].legend()

axs[1].plot(epoch_log, N_log, label="N_est")
axs[1].plot(epoch_log, Wi_log, label="Wi_est")
axs[1].plot(epoch_log, J_log, label="J_est")
axs[1].legend()

# %%
# Imprimindo os parametros ajustados
best_state.params['params']['N'], best_state.params['params']['Wi'], best_state.params['params']['J']
# Out:
# (Array(185.36046, dtype=float32),
#  Array(99.99402, dtype=float32),
#  Array(100.007965, dtype=float32))

# %%
# Predict using the trained model
predictions = vmap(best_state.apply_fn, (None, 0))(best_state.params, X_test)

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MAE): 0.58573025
# Mean Squared Error (MSE): 0.5895798
# Root Mean Squared Error (RMSE): 0.76784104

# %%
# Avaliando a rede neural depois do treinamento considerando o teste

fig, ax = plt.subplots(1,1, figsize=(10,10/1.618))

ax.scatter(jnp.arange(0, len(y_test), 1), y_test, label=r'$u_{meas}$', color='black')
ax.plot(jnp.arange(0, len(y_test), 1), predictions, label=r'$u_{pred}$', color='red')

ax.legend()
ax.set_title('Previsão depois do ajuste do modelo')
# Out:
# Text(0.5, 1.0, 'Previsão depois do ajuste do modelo')

# %%
# Avaliando a rede neural depois do treinamento considerando todo o histórico
u_pred = vmap(best_state.apply_fn, (None, 0))(best_state.params, X)

fig, ax = plt.subplots(1,1, figsize=(10,10/1.618))

ax.scatter(df['t'].values, df["p"].values, label=r'$u_{meas}$', color='black')
ax.plot(df["t"].values[window_size:], u_pred, label=r'$u_{pred}$', color='red')

ax.legend()
ax.set_title('Previsão depois do ajuste do modelo')
# Out:
# Text(0.5, 1.0, 'Previsão depois do ajuste do modelo')
